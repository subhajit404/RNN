# %% [markdown]
# <a href="https://colab.research.google.com/github/subhajit404/RNN/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('qoute_dataset.csv')

# %%
quotes = df['quote']

# %%
quotes = quotes.str.lower()

# %%
quotes = quotes.str.replace(r'[^\w\s]', '', regex=True)

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
vocab_size = 10000
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(quotes)

# %%
quotes.str.split().explode().unique().size
# Out:
# 8724

# %%
word_idx = tokenizer.word_index
print(len(word_idx))
list(word_idx.items())[:10]
# Out:
# 8723
# [('the', 1),
#  ('you', 2),
#  ('to', 3),
#  ('and', 4),
#  ('a', 5),
#  ('i', 6),
#  ('is', 7),
#  ('of', 8),
#  ('that', 9),
#  ('it', 10)]

# %%
sequence = tokenizer.texts_to_sequences(quotes)

# %%
X = []
y = []


for seq in sequence:
    for i in range(1,len(seq)):
        input_seq = seq[:i]
        output_seq = seq[i]
        X.append(input_seq)
        y.append(output_seq)

# %%
max_len= max(len(x) for x in X)
max_len
# Out:
# 745

# %%
import tensorflow
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
X_pad = pad_sequences(X,maxlen=max_len,padding='pre')

# %%
y= np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y_one_hot = to_categorical(y,num_classes= vocab_size)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense,SimpleRNN

# %%
emb_dim = 50
rnn_units = 128

# %%
lstm_model = Sequential()
lstm_model.add(
    Embedding(input_dim=vocab_size,output_dim=emb_dim,input_length=max_len)
)

lstm_model.add(LSTM(units=rnn_units))
lstm_model.add(Dense(units=vocab_size,activation='softmax'))

# %%
lstm_model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm_model.fit(X_pad,y_one_hot ,epochs=100,batch_size=128,verbose=1)
# Out:
# Epoch 1/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 39s 48ms/step - accuracy: 0.0407 - loss: 6.7202
# Epoch 2/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 33s 49ms/step - accuracy: 0.0628 - loss: 6.2527
# Epoch 3/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 34s 51ms/step - accuracy: 0.0894 - loss: 5.9728
# Epoch 4/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 53ms/step - accuracy: 0.1045 - loss: 5.7564
# Epoch 5/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1154 - loss: 5.5676
# Epoch 6/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1246 - loss: 5.3926
# Epoch 7/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1337 - loss: 5.2336
# Epoch 8/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1414 - loss: 5.0861
# Epoch 9/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1485 - loss: 4.9452
# Epoch 10/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1550 - loss: 4.8104
# Epoch 11/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1624 - loss: 4.6792
# Epoch 12/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1706 - loss: 4.5502
# Epoch 13/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1796 - loss: 4.4244
# Epoch 14/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.1914 - loss: 4.3015
# Epoch 15/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 34s 52ms/step - accuracy: 0.2030 - loss: 4.1822
# Epoch 16/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.2191 - loss: 4.0671
# Epoch 17/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.2335 - loss: 3.9580
# Epoch 18/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.2498 - loss: 3.8533
# Epoch 19/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.2632 - loss: 3.7566
# Epoch 20/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 34s 52ms/step - accuracy: 0.2775 - loss: 3.6654
# Epoch 21/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.2909 - loss: 3.5805
# Epoch 22/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.3016 - loss: 3.5007
# Epoch 23/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 34s 52ms/step - accuracy: 0.3134 - loss: 3.4264
# Epoch 24/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.3247 - loss: 3.3547
# Epoch 25/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.3361 - loss: 3.2874
# Epoch 26/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.3459 - loss: 3.2233
# Epoch 27/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.3554 - loss: 3.1620
# Epoch 28/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 34s 52ms/step - accuracy: 0.3649 - loss: 3.1028
# Epoch 29/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.3750 - loss: 3.0441
# Epoch 30/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.3840 - loss: 2.9905
# Epoch 31/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 34s 51ms/step - accuracy: 0.3924 - loss: 2.9372
# Epoch 32/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.4011 - loss: 2.8857
# Epoch 33/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.4108 - loss: 2.8365
# Epoch 34/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 34s 52ms/step - accuracy: 0.4183 - loss: 2.7877
# Epoch 35/100
# 666/666 ━━━━━━━━━━━━━━━━━━━━